# %% [markdown]
# Writing YAML from Python.
#
#     Python dictionary
#             │
#             │ yaml.safe_dump()
#             ▼
#         YAML file

# %% [markdown]
# In your project, create: Create a new Python file
#
# yaml-learning/
#     │
#     ├── enterprise_rag.yaml
#     │
#     ├── read_yaml.py
#     │
#     └── write_yaml.py

# %%
import yaml

# craete a Python dictionary to hold the configuration to convert to YAML
config = {
    "application": {
        "name": "Enterprise RAG application",
        "version": 1.0
    },

    "llm": {
        "provider": "Groq",
        "model": "llama-3.1-8b-instant",
        "temperature": 0
    },

    "embedding": {
        "provider": "sentence-transformers",
        "model": "all-MiniLM-L6-v2"
    }
}

print("Configuration dictionary:", config)

# %%
with open("generated_config.yaml", "w") as file:
    yaml.safe_dump(config, file)

# %% [markdown]
# Understand safe_dump()
#     Convert the Python object config into YAML format and write it into file.
#
# Operation	PyYAML
# ##############################
# YAML → Python	yaml.safe_load()
# Python → YAML	yaml.safe_dump()
